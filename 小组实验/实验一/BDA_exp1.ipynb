# %%
import chardet
import pandas as pd
from pandas import DataFrame
import numpy as np

# 检测文件编码
with open('data.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 使用检测到的编码读取数据
primitive_data = pd.read_csv('data.csv', encoding=result['encoding'])
primitive_data
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
primitive_data_1=primitive_data.dropna(how='any')
primitive_data_1
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
data_after_filter_2
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
data_before_sample=data_after_filter_2
columns=data_before_sample.columns
weight_sample=data_before_sample.copy()
weight_sample['weight']=0
for i in weight_sample.index:
    if weight_sample.at[i, 'to_level'] == '一般节点':
        weight = 1
    else:
        weight = 5
    weight_sample.at[i, 'weight'] = weight

weight_sample_finish=weight_sample.sample(n=50,weights='weight')
#data_before_sample=data_before_sample[columns]
weight_sample_finish=weight_sample[columns]
weight_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
random_sample=data_before_sample
random_sample_finish=random_sample.sample(n=50)
random_sample_finish=random_sample_finish[columns]
random_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 29          63        230        通辽       一般节点    2701       71      大连
# 724       4069       1205        宁波       一般节点   36036       52      长春
# 97         474        416       哈尔滨       一般节点    1257      178      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 614        180        252      呼和浩特       一般节点   36036       52      长春
# 539         47        425        通辽       一般节点    3227      787      济南
# 1063        47        314        通辽       一般节点      47      252      通辽
# 644         47        314        通辽       一般节点      96      152    呼和浩特
# 38          96        111      呼和浩特       一般节点    3227      468      济南
# 150        591        582        绥化       一般节点    2701      619      大连
# 50          96        155      呼和浩特       一般节点    1536      681      广州
# 432        591       1106        绥化       一般节点    3227      781      济南
# 96         474        360       哈尔滨       一般节点    2473      946      吉林
# 1057        47        243        通辽       一般节点    2473      769      吉林
# 573      36036         20        长春       一般节点     235     1621      北京
# 7           47        250        通辽       一般节点    2473      762      吉林
# 67         180         28      呼和浩特       一般节点    1385      133      广州
# 546         63         60        通辽       一般节点    4360      468      南京
# 929       4360        468        南京       一般节点    1997      464      天津
# 23          63         62        通辽       一般节点   36422      394      天津
# 429        591       1080        绥化       一般节点     180       52    呼和浩特
# 149        591        560        绥化       一般节点   36422      346      天津
# 162        591       1274        绥化       一般节点    1129      203      上海
# 377        474        467       哈尔滨       一般节点    5058       70      南宁
# 355        180        200      呼和浩特       一般节点    1536     2309      广州
# 824         47        252        通辽       一般节点     474     1389     哈尔滨
# 110        474        672       哈尔滨       一般节点      47      242      通辽
# 137        591         23        绥化       一般节点      63        6      通辽
# 125        474       1374       哈尔滨       一般节点    2050      336     石家庄
# 174        787        316        玉溪       一般节点    1257      177      上海
# 383        474        670       哈尔滨       一般节点    5058      144      南宁
# 42          96        123      呼和浩特       一般节点    2841      237      郑州
# 35          96        102      呼和浩特       一般节点    2549      852      沈阳
# 98         474        417       哈尔滨       一般节点    1997       41      天津
# 440        591       1290        绥化       一般节点    1756     1027      北京
# 79         180        192      呼和浩特       一般节点     591      586      绥化
# 994         63          6        通辽       一般节点    2701      135      大连
# 6           47        249        通辽       一般节点    1997       85      天津
# 122        474       1272       哈尔滨       一般节点    2473     1043      吉林
# 893         63         70        通辽       一般节点    1997       90      天津
# 530         47        249        通辽       一般节点    2473      799      吉林
# 278         47        241        通辽       一般节点    4953      725      贵阳
# 19          63         12        通辽       一般节点     180      252    呼和浩特
# 339        180         18      呼和浩特       一般节点      47      241      通辽
# 738       2473        803        吉林       一般节点     235     1621      北京
# 599        474        672       哈尔滨       一般节点    2050      336     石家庄
# 59          96        391      呼和浩特       一般节点      47      417      通辽
# 389        474        682       哈尔滨       一般节点    1997       85      天津
# 775         96        134      呼和浩特       一般节点     180       98    呼和浩特
#
#      to_level      traffic     bandwidth
# 29       网络核心  50037668767  1.000000e+11
# 724      一般节点  50994646887  1.000000e+11
# 97       网络核心  50599061005  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 614      一般节点  49966571450  1.000000e+11
# 539      网络核心  49862690338  1.000000e+11
# 1063     一般节点  49900452417  1.000000e+11
# 644      一般节点  51384841448  1.000000e+11
# 38       网络核心  48575689938  1.000000e+11
# 150      网络核心  50838395442  1.000000e+11
# 50       网络核心  51538493830  1.000000e+11
# 432      网络核心  48568999606  1.000000e+11
# 96       一般节点  51819320173  1.000000e+11
# 1057     一般节点  49117847542  1.000000e+11
# 573      网络核心  50173217899  1.000000e+11
# 7        一般节点  49108721007  1.000000e+11
# 67       网络核心  52798223188  1.000000e+11
# 546      一般节点  47970715088  1.000000e+11
# 929      网络核心  49145116989  1.000000e+11
# 23       网络核心  50322780029  1.000000e+11
# 429      一般节点  49419561900  1.000000e+11
# 149      网络核心  49682522061  1.000000e+11
# 162      网络核心  49321244844  1.000000e+11
# 377      一般节点  51745421052  1.000000e+11
# 355      网络核心  49873632464  1.000000e+11
# 824      一般节点  51228405663  1.000000e+11
# 110      一般节点  51555817613  1.000000e+11
# 137      一般节点  49462640634  1.000000e+11
# 125      网络核心  50242784823  1.000000e+11
# 174      网络核心  51407063255  1.000000e+11
# 383      一般节点  50998204735  1.000000e+11
# 42       网络核心  48077485179  1.000000e+11
# 35       网络核心  48368154112  1.000000e+11
# 98       网络核心  51874083489  1.000000e+11
# 440      网络核心  50090927530  1.000000e+11
# 79       一般节点  49504348509  1.000000e+11
# 994      网络核心  50680536460  1.000000e+11
# 6        网络核心  50499586948  1.000000e+11
# 122      一般节点  49735704801  1.000000e+11
# 893      网络核心  49056576007  1.000000e+11
# 530      一般节点  49803820036  1.000000e+11
# 278      一般节点  50008939996  1.000000e+11
# 19       一般节点  49290094443  1.000000e+11
# 339      一般节点  51793025548  1.000000e+11
# 738      网络核心  49820870504  1.000000e+11
# 599      网络核心  51340689424  1.000000e+11
# 59       一般节点  51570663870  1.000000e+11
# 389      网络核心  50053473543  1.000000e+11
# 775      一般节点  51993612239  1.000000e+11

# %%
ybjd=data_before_sample.loc[data_before_sample['to_level']=='一般节点']
wlhx=data_before_sample.loc[data_before_sample['to_level']=='网络核心']
after_sample=pd.concat([ybjd.sample(17),wlhx.sample(33)])
after_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 383        474        670       哈尔滨       一般节点    5058      144      南宁
# 151        591        586        绥化       一般节点     180      192    呼和浩特
# 493         47        251        通辽       一般节点      63      286      通辽
# 298         63         62        通辽       一般节点     474      683     哈尔滨
# 392        474       1228       哈尔滨       一般节点      96      134    呼和浩特
# 760       5058         70        南宁       一般节点      96      460    呼和浩特
# 984       4360        468        南京       一般节点      96      108    呼和浩特
# 19          63         12        通辽       一般节点     180      252    呼和浩特
# 806        180         20      呼和浩特       一般节点     474      670     哈尔滨
# 766       5058        144        南宁       一般节点     180       30    呼和浩特
# 1031       591         23        绥化       一般节点      96      152    呼和浩特
# 360        180        218      呼和浩特       一般节点    4069     1195      宁波
# 491         47        249        通辽       一般节点   36539     1140      杭州
# 376        474        460       哈尔滨       一般节点    3757      122      福州
# 783        591         23        绥化       一般节点     180      218    呼和浩特
# 771         96        124      呼和浩特       一般节点     180       50    呼和浩特
# 614        180        252      呼和浩特       一般节点   36036       52      长春
# 323         96        141      呼和浩特       一般节点    2050      391     石家庄
# 54          96        159      呼和浩特       一般节点    2360      266      太原
# 456        787        418        玉溪       一般节点   36422      124      天津
# 433        591       1112        绥化       一般节点    2360      236      太原
# 436        591       1266        绥化       一般节点    2050      505     石家庄
# 395        474       1259       哈尔滨       一般节点    2549      835      沈阳
# 430        591       1082        绥化       一般节点    1257      560      上海
# 437        591       1274        绥化       一般节点    1997      250      天津
# 23          63         62        通辽       一般节点   36422      394      天津
# 725       2473       1460        吉林       一般节点   36422      446      天津
# 150        591        582        绥化       一般节点    2701      619      大连
# 378        474        472       哈尔滨       一般节点    3643      902      武汉
# 159        591       1250        绥化       一般节点     235     1749      北京
# 375        474        422       哈尔滨       一般节点    3213      587      重庆
# 281         47        249        通辽       一般节点    1536     1882      广州
# 547         63         62        通辽       一般节点    1756     1067      北京
# 407        591         11        绥化       一般节点     235      112      北京
# 426        591        586        绥化       一般节点   36422      124      天津
# 643        474        422       哈尔滨       一般节点    2549      835      沈阳
# 485         47         71        通辽       一般节点   36272      133      太原
# 893         63         70        通辽       一般节点    1997       90      天津
# 109        474        671       哈尔滨       一般节点    2549      919      沈阳
# 322         96        136      呼和浩特       一般节点    3227      389      济南
# 950      36036        499        长春       一般节点    2050      293     石家庄
# 124        474       1311       哈尔滨       一般节点    2549     1570      沈阳
# 425        591        582        绥化       一般节点    2701       71      大连
# 34          96         99      呼和浩特       一般节点    1257      560      上海
# 1041       180         20      呼和浩特       一般节点   36422      394      天津
# 540         47        427        通辽       一般节点    2549     1430      沈阳
# 722       4360        468        南京       一般节点    3443      117      青岛
# 566        591        586        绥化       一般节点    1129      514      上海
# 701       2473        803        吉林       一般节点    2194      406      唐山
# 144        591         98        绥化       一般节点    2701      195      大连
#
#      to_level      traffic     bandwidth
# 383      一般节点  50998204735  1.000000e+11
# 151      一般节点  49061517661  1.000000e+11
# 493      一般节点  49254299513  1.000000e+11
# 298      一般节点  50533229665  1.000000e+11
# 392      一般节点  51278220999  1.000000e+11
# 760      一般节点  49703011825  1.000000e+11
# 984      一般节点  51700762978  1.000000e+11
# 19       一般节点  49290094443  1.000000e+11
# 806      一般节点  50581993828  1.000000e+11
# 766      一般节点  50481413185  1.000000e+11
# 1031     一般节点  51357214855  1.000000e+11
# 360      一般节点  50955164303  1.000000e+11
# 491      一般节点  50888438116  1.000000e+11
# 376      一般节点  48394911971  1.000000e+11
# 783      一般节点  50522034278  1.000000e+11
# 771      一般节点  51101128426  1.000000e+11
# 614      一般节点  49966571450  1.000000e+11
# 323      网络核心  49814111100  1.000000e+11
# 54       网络核心  51625089370  1.000000e+11
# 456      网络核心  50721158025  1.000000e+11
# 433      网络核心  50670449325  1.000000e+11
# 436      网络核心  51285397493  1.000000e+11
# 395      网络核心  49504676343  1.000000e+11
# 430      网络核心  49355162407  1.000000e+11
# 437      网络核心  50278361522  1.000000e+11
# 23       网络核心  50322780029  1.000000e+11
# 725      网络核心  49869730875  1.000000e+11
# 150      网络核心  50838395442  1.000000e+11
# 378      网络核心  50470657254  1.000000e+11
# 159      网络核心  49636424242  1.000000e+11
# 375      网络核心  50424883915  1.000000e+11
# 281      网络核心  47584217074  1.000000e+11
# 547      网络核心  49632977575  1.000000e+11
# 407      网络核心  50766117914  1.000000e+11
# 426      网络核心  50282882315  1.000000e+11
# 643      网络核心  50003053222  1.000000e+11
# 485      网络核心  50529263033  1.000000e+11
# 893      网络核心  49056576007  1.000000e+11
# 109      网络核心  50446722135  1.000000e+11
# 322      网络核心  50541979348  1.000000e+11
# 950      网络核心  50524728588  1.000000e+11
# 124      网络核心  49783212426  1.000000e+11
# 425      网络核心  49584780636  1.000000e+11
# 34       网络核心  49753614568  1.000000e+11
# 1041     网络核心  50353235399  1.000000e+11
# 540      网络核心  50264080533  1.000000e+11
# 722      网络核心  49458752996  1.000000e+11
# 566      网络核心  49995510331  1.000000e+11
# 701      网络核心  48906180396  1.000000e+11
# 144      网络核心  50256295026  1.000000e+11

# %%
def systematic_sampling(data, sample_size):
    N = len(data)  
    k = N // sample_size  
    start = np.random.randint(0, k)  
    indices = np.arange(start, N, k)[:sample_size] 
    sample = data.iloc[indices]  
    return sample

systematic_sample = systematic_sampling(primitive_data,50)
systematic_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 6           47        249        通辽       一般节点    1997       85      天津
# 28          63        228        通辽       一般节点     235     1506      北京
# 50          96        155      呼和浩特       一般节点    1536      681      广州
# 72         180         42      呼和浩特       一般节点   36539     1140      杭州
# 94         180        485      呼和浩特       一般节点   36422      102      天津
# 116        474       1227       哈尔滨       一般节点    2841      341      郑州
# 138        591         27        绥化       一般节点    3443      117      青岛
# 160        591       1258        绥化       一般节点    4448      127      无锡
# 182       1997         38        天津       网络核心    3227      766      济南
# 204       1997        127        天津       网络核心    2360      197      太原
# 226       1997        251        天津       网络核心    1756      273      北京
# 248       2050        290       石家庄       网络核心    2360      341      太原
# 270       2050        336       石家庄       网络核心     474     1374     哈尔滨
# 292         63          6        通辽       一般节点    2841      418      郑州
# 314         96        114      呼和浩特       一般节点    4561     1086      成都
# 336         96        407      呼和浩特       一般节点    3227      188      济南
# 358        180        210      呼和浩特       一般节点    1756      642      北京
# 380        474        474       哈尔滨       一般节点    3227      701      济南
# 402        474       1399       哈尔滨       一般节点     180      252    呼和浩特
# 424        591        560        绥化       一般节点     235     1506      北京
# 446        787         61        玉溪       一般节点     235      100      北京
# 468       1997         88        天津       网络核心      47      314      通辽
# 490         47        243        通辽       一般节点    1385     2778      广州
# 512       1997        726        天津       网络核心   36272      235      太原
# 534         47        258        通辽       一般节点    1997       84      天津
# 556         63        282        通辽       一般节点      63        6      通辽
# 578         63         70        通辽       一般节点     235     1749      北京
# 600         96        124      呼和浩特       一般节点    1756     1127      北京
# 622        180         20      呼和浩特       一般节点   36036      499      长春
# 644         47        314        通辽       一般节点      96      152    呼和浩特
# 666       1385       2778        广州       网络核心    2549      852      沈阳
# 688      36272        235        太原       网络核心    1756     1187      北京
# 710       1997         84        天津       网络核心     591      586      绥化
# 732         96        141      呼和浩特       一般节点   36036      499      长春
# 754       3227        530        济南       网络核心      96      346    呼和浩特
# 776       1997        122        天津       网络核心     180      188    呼和浩特
# 798      36422        230        天津       网络核心     474      422     哈尔滨
# 820       1997        250        天津       网络核心     474     1272     哈尔滨
# 842       2050        505       石家庄       网络核心     591       98      绥化
# 864       1997        729        天津       网络核心     591     1300      绥化
# 886       2701        135        大连       网络核心    1997       44      天津
# 908       2473        803        吉林       一般节点      47       71      通辽
# 930       1756       1067        北京       网络核心    1997      465      天津
# 952       2701        619        大连       网络核心    2050      295     石家庄
# 974       1536       1882        广州       网络核心      63      224      通辽
# 996       2701        227        大连       网络核心   36036       20      长春
# 1018       474        672       哈尔滨       一般节点    1756      585      北京
# 1040      2701        181        大连       网络核心   36422      258      天津
# 1062       474        422       哈尔滨       一般节点    1756     1027      北京
# 1084      2194        406        唐山       网络核心   36272      133      太原
#
#      to_level      traffic     bandwidth
# 6        网络核心  50499586948  1.000000e+11
# 28       网络核心  49436165249  1.000000e+11
# 50       网络核心  51538493830  1.000000e+11
# 72       一般节点  49293665157  1.000000e+11
# 94       网络核心  52460156321  1.000000e+11
# 116      网络核心  48505909225  1.000000e+11
# 138      网络核心  49213859972  1.000000e+11
# 160      一般节点  50322958171  1.000000e+11
# 182      网络核心  49896147267  1.000000e+11
# 204      网络核心  48186194374  1.000000e+11
# 226      网络核心  46975713471  1.000000e+11
# 248      网络核心  51585396120  1.000000e+11
# 270      一般节点  50271337625  1.000000e+11
# 292      网络核心  51392218854  1.000000e+11
# 314      网络核心  49729944227  1.000000e+11
# 336      网络核心  50219393940  1.000000e+11
# 358      网络核心  49636949412  1.000000e+11
# 380      网络核心  51078772989  1.000000e+11
# 402      一般节点  49271182579  1.000000e+11
# 424      网络核心  48754882922  1.000000e+11
# 446      网络核心  49408483245  1.000000e+11
# 468      一般节点  51109843962  1.000000e+11
# 490      网络核心  50075073640  1.000000e+11
# 512      网络核心  49715195160  1.000000e+11
# 534      网络核心  50060087433  1.000000e+11
# 556      一般节点  49489299594  1.000000e+11
# 578      网络核心  50871621460  1.000000e+11
# 600      网络核心  48884918110  1.000000e+11
# 622      一般节点  49636788433  1.000000e+11
# 644      一般节点  51384841448  1.000000e+11
# 666      网络核心  49095842125  1.000000e+11
# 688      网络核心  49964131285  1.000000e+11
# 710      一般节点  48924224727  1.000000e+11
# 732      一般节点  47474335913  1.000000e+11
# 754      一般节点  49612302890  1.000000e+11
# 776      一般节点  48726032367  1.000000e+11
# 798      一般节点            0  1.000000e+11
# 820      一般节点  49521483342  1.000000e+11
# 842      一般节点  49282373287  1.000000e+11
# 864      一般节点  50093280961  1.000000e+11
# 886      网络核心  49311218380  1.000000e+11
# 908      一般节点  51423663989  1.000000e+11
# 930      网络核心  49056142852  1.000000e+11
# 952      网络核心  49103709149  1.000000e+11
# 974      一般节点  48655031586  1.000000e+11
# 996      一般节点  51033589542  1.000000e+11
# 1018     网络核心  48132652830  1.000000e+11
# 1040     网络核心  48436729293  1.000000e+11
# 1062     网络核心  49590902097  1.000000e+11
# 1084     网络核心  48850115329  1.000000e+11

# %%
def cluster_sampling(data, num_clusters, cluster_column):
    unique_clusters = data[cluster_column].unique()
    selected_clusters = np.random.choice(unique_clusters, num_clusters, replace=False)
    sample = data[data[cluster_column].isin(selected_clusters)]
    return sample

cluster_sample = cluster_sampling(primitive_data, 3, 'from_city')
cluster_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 567       2701        300        大连       网络核心   36036      499      长春
# 571       2701        135        大连       网络核心    2194      264      唐山
# 583       2473        946        吉林       一般节点   36539     1146      杭州
# 588       3227        344        济南       网络核心    4953      725      贵阳
# 593       2473        803        吉林       一般节点    3227      705      济南
# ...        ...        ...       ...        ...     ...      ...     ...
# 1094      2701        300        大连       网络核心     235     1958      北京
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1106      2701        227        大连       网络核心     235     1663      北京
# 1111      2701        195        大连       网络核心   36272      235      太原
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 567      一般节点  50207589348  1.000000e+11
# 571      网络核心  49363764010  1.000000e+11
# 583      一般节点  50631070410  1.000000e+11
# 588      一般节点  50925677715  1.000000e+11
# 593      网络核心  49383348895  1.000000e+11
# ...       ...          ...           ...
# 1094     网络核心  50541875029  1.000000e+11
# 1097     一般节点  48409925693  1.000000e+11
# 1106     网络核心  49364931565  1.000000e+11
# 1111     网络核心  49757975617  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [82 rows x 10 columns]
