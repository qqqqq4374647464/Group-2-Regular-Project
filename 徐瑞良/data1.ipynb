# %%
data =123
data
# Out:
# 123

# %%
import chardet
import pandas as pd
from pandas import DataFrame
import numpy as np

# 检测文件编码
with open('D:/大数据分析实践 实验内容/data.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 使用检测到的编码读取数据
primitive_data = pd.read_csv('D:/大数据分析实践 实验内容/data.csv', encoding=result['encoding'])
primitive_data
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
import chardet
import pandas as pd
from pandas import DataFrame
import numpy as np

primitive_data = pd.read_csv('D:/大数据分析实践 实验内容/data.csv')
primitive_data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 6
#       3 from pandas import DataFrame
#       4 import numpy as np
# ----> 6 primitive_data = pd.read_csv('D:/大数据分析实践 实验内容/data.csv')
#       7 primitive_data
#
# File D:\Conda\envs\ai_clone\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File D:\Conda\envs\ai_clone\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File D:\Conda\envs\ai_clone\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File D:\Conda\envs\ai_clone\lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File D:\Conda\envs\ai_clone\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 99: invalid start byte

# %%
import chardet
import pandas as pd
from pandas import DataFrame
import numpy as np

# 检测文件编码
with open('D:/大数据分析实践 实验内容/data.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 使用检测到的编码读取数据
primitive_data = pd.read_csv('D:/大数据分析实践 实验内容/data.csv', encoding=result['encoding'])
primitive_data
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
primitive_data_1=primitive_data.dropna(how='any')
primitive_data_1
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
data_after_filter_2
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
data_before_sample=data_after_filter_2
columns=data_before_sample.columns
weight_sample=data_before_sample.copy()
weight_sample['weight']=0
for i in weight_sample.index:
    if weight_sample.at[i, 'to_level'] == '一般节点':
        weight = 1
    else:
        weight = 5
    weight_sample.at[i, 'weight'] = weight

weight_sample_finish=weight_sample.sample(n=50,weights='weight')
#data_before_sample=data_before_sample[columns]
weight_sample_finish=weight_sample[columns]
weight_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
random_sample=data_before_sample
random_sample_finish=random_sample.sample(n=50)
random_sample_finish=random_sample_finish[columns]
random_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 691       2473        946        吉林       一般节点    1756     1117      北京
# 851         47        314        通辽       一般节点     591     1028      绥化
# 530         47        249        通辽       一般节点    2473      799      吉林
# 490         47        243        通辽       一般节点    1385     2778      广州
# 578         63         70        通辽       一般节点     235     1749      北京
# 497         47        260        通辽       一般节点   36422      350      天津
# 167        787         51        玉溪       一般节点    4561     1033      成都
# 173        787        307        玉溪       一般节点    4953      686      贵阳
# 660         63        224        通辽       一般节点    2701       71      大连
# 414        591         29        绥化       一般节点     235     1649      北京
# 28          63        228        通辽       一般节点     235     1506      北京
# 130        474       1470       哈尔滨       一般节点    2473     1460      吉林
# 180        787        360        玉溪       一般节点    3615      191      长沙
# 178        787        326        玉溪       一般节点    3213      597      重庆
# 68         180         30      呼和浩特       一般节点     235     1661      北京
# 566        591        586        绥化       一般节点    1129      514      上海
# 57          96        379      呼和浩特       一般节点    1756     1187      北京
# 135        591         17        绥化       一般节点    3443      186      青岛
# 436        591       1266        绥化       一般节点    2050      505     石家庄
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# 939         63          6        通辽       一般节点    2050      269     石家庄
# 440        591       1290        绥化       一般节点    1756     1027      北京
# 847         47        252        通辽       一般节点     591      560      绥化
# 115        474        683       哈尔滨       一般节点    1997       84      天津
# 61          96        407      呼和浩特       一般节点    4069     1196      宁波
# 385        474        672       哈尔滨       一般节点    1756      802      北京
# 53          96        158      呼和浩特       一般节点    2841      545      郑州
# 132        591         11        绥化       一般节点    2994      488      洛阳
# 667      36539       1140        杭州       一般节点    3227      781      济南
# 59          96        391      呼和浩特       一般节点      47      417      通辽
# 40          96        117      呼和浩特       一般节点    2050      505     石家庄
# 500         47        425        通辽       一般节点   36272      247      太原
# 644         47        314        通辽       一般节点      96      152    呼和浩特
# 175        787        317        玉溪       一般节点    5058      118      南宁
# 614        180        252      呼和浩特       一般节点   36036       52      长春
# 94         180        485      呼和浩特       一般节点   36422      102      天津
# 616      36036         54        长春       一般节点   36272      105      太原
# 434        591       1250        绥化       一般节点    3227      468      济南
# 1023        96        134      呼和浩特       一般节点      96      124    呼和浩特
# 439        591       1286        绥化       一般节点      47      243      通辽
# 445        787         60        玉溪       一般节点      47      314      通辽
# 1021      2473        762        吉林       一般节点    1997      464      天津
# 330         96        336      呼和浩特       一般节点    1756     1106      北京
# 155        591       1082        绥化       一般节点    2994      430      洛阳
# 425        591        582        绥化       一般节点    2701       71      大连
# 363        180        254      呼和浩特       一般节点    2360       62      太原
# 555         63        278        通辽       一般节点   36036       18      长春
# 938      36036         18        长春       一般节点    1997      729      天津
# 52          96        157      呼和浩特       一般节点    2050      443     石家庄
# 656       4069       1196        宁波       一般节点     180      264    呼和浩特
#
#      to_level      traffic     bandwidth
# 691      网络核心  48978564669  1.000000e+11
# 851      一般节点  50080623466  1.000000e+11
# 530      一般节点  49803820036  1.000000e+11
# 490      网络核心  50075073640  1.000000e+11
# 578      网络核心  50871621460  1.000000e+11
# 497      网络核心  49613775497  1.000000e+11
# 167      网络核心  51033155364  1.000000e+11
# 173      一般节点  49399787960  1.000000e+11
# 660      网络核心  50555895575  1.000000e+11
# 414      网络核心  49268934149  1.000000e+11
# 28       网络核心  49436165249  1.000000e+11
# 130      一般节点  49047884661  1.000000e+11
# 180      一般节点  49629725686  1.000000e+11
# 178      网络核心  48608499709  1.000000e+11
# 68       网络核心  49596659754  1.000000e+11
# 566      网络核心  49995510331  1.000000e+11
# 57       网络核心  49400869697  1.000000e+11
# 135      网络核心  49474305249  1.000000e+11
# 436      网络核心  51285397493  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# 939      网络核心  49208374165  1.000000e+11
# 440      网络核心  50090927530  1.000000e+11
# 847      一般节点  51065218921  1.000000e+11
# 115      网络核心  49446798762  1.000000e+11
# 61       一般节点  49745162804  1.000000e+11
# 385      网络核心  50199756109  1.000000e+11
# 53       网络核心  51342500152  1.000000e+11
# 132      网络核心  51159567570  1.000000e+11
# 667      网络核心  49721314562  1.000000e+11
# 59       一般节点  51570663870  1.000000e+11
# 40       网络核心  48814619370  1.000000e+11
# 500      网络核心  49644611631  1.000000e+11
# 644      一般节点  51384841448  1.000000e+11
# 175      一般节点  49579743371  1.000000e+11
# 614      一般节点  49966571450  1.000000e+11
# 94       网络核心  52460156321  1.000000e+11
# 616      网络核心  50464551947  1.000000e+11
# 434      网络核心  50478302588  1.000000e+11
# 1023     一般节点  49523879533  1.000000e+11
# 439      一般节点  50053279322  1.000000e+11
# 445      一般节点  49484495071  1.000000e+11
# 1021     网络核心  47991126091  1.000000e+11
# 330      网络核心  51277669375  1.000000e+11
# 155      网络核心  49899654326  1.000000e+11
# 425      网络核心  49584780636  1.000000e+11
# 363      网络核心  50252917820  1.000000e+11
# 555      一般节点  50478302302  1.000000e+11
# 938      网络核心  47728327758  1.000000e+11
# 52       网络核心  50096366926  1.000000e+11
# 656      一般节点  49766912004  1.000000e+11

# %%
ybjd=data_before_sample.loc[data_before_sample['to_level']=='一般节点']
wlhx=data_before_sample.loc[data_before_sample['to_level']=='网络核心']
after_sample=pd.concat([ybjd.sample(17),wlhx.sample(33)])
after_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 294         63         12        通辽       一般节点     474      417     哈尔滨
# 787      36036         54        长春       一般节点     180      256    呼和浩特
# 850        474        422       哈尔滨       一般节点     591      638      绥化
# 173        787        307        玉溪       一般节点    4953      686      贵阳
# 408        591         13        绥化       一般节点     180      264    呼和浩特
# 160        591       1258        绥化       一般节点    4448      127      无锡
# 311         96        105      呼和浩特       一般节点    2473      804      吉林
# 1057        47        243        通辽       一般节点    2473      769      吉林
# 445        787         60        玉溪       一般节点      47      314      通辽
# 392        474       1228       哈尔滨       一般节点      96      134    呼和浩特
# 13          47        314        通辽       一般节点      96      152    呼和浩特
# 793        180         20      呼和浩特       一般节点     474      359     哈尔滨
# 644         47        314        通辽       一般节点      96      152    呼和浩特
# 148        591        558        绥化       一般节点   36036      499      长春
# 45          96        134      呼和浩特       一般节点      47      252      通辽
# 122        474       1272       哈尔滨       一般节点    2473     1043      吉林
# 757       3615        179        长沙       一般节点      96      391    呼和浩特
# 35          96        102      呼和浩特       一般节点    2549      852      沈阳
# 142        591         64        绥化       一般节点   36272      105      太原
# 566        591        586        绥化       一般节点    1129      514      上海
# 66         180         26      呼和浩特       一般节点   36272      133      太原
# 63         180         10      呼和浩特       一般节点    2994      270      洛阳
# 324         96        152      呼和浩特       一般节点    3643      559      武汉
# 533         47        252        通辽       一般节点    1536      585      广州
# 554         63        232        通辽       一般节点    3443      186      青岛
# 2           47        240        通辽       一般节点    1756      802      北京
# 485         47         71        通辽       一般节点   36272      133      太原
# 152        591        638        绥化       一般节点    2194      264      唐山
# 18          63         10        通辽       一般节点     235      106      北京
# 331         96        346      呼和浩特       一般节点    1756     1128      北京
# 489         47        242        通辽       一般节点    2194      406      唐山
# 349        180         52      呼和浩特       一般节点    3227      449      济南
# 373        474        417       哈尔滨       一般节点    2841      438      郑州
# 58          96        383      呼和浩特       一般节点    5242      783      西安
# 442        787         51        玉溪       一般节点    2549      836      沈阳
# 415        591         56        绥化       一般节点   36422      230      天津
# 428        591       1028        绥化       一般节点   36422      230      天津
# 881        591        586        绥化       一般节点    1997       39      天津
# 600         96        124      呼和浩特       一般节点    1756     1127      北京
# 925       4360        472        南京       一般节点    1997      251      天津
# 424        591        560        绥化       一般节点     235     1506      北京
# 363        180        254      呼和浩特       一般节点    2360       62      太原
# 330         96        336      呼和浩特       一般节点    1756     1106      北京
# 11          47        259        通辽       一般节点    1756      245      北京
# 125        474       1374       哈尔滨       一般节点    2050      336     石家庄
# 738       2473        803        吉林       一般节点     235     1621      北京
# 488         47        241        通辽       一般节点    3443      503      青岛
# 53          96        158      呼和浩特       一般节点    2841      545      郑州
# 620        180        264      呼和浩特       一般节点    1129      546      上海
# 134        591         15        绥化       一般节点    1385     1490      广州
#
#      to_level      traffic     bandwidth
# 294      一般节点  48667628783  1.000000e+11
# 787      一般节点  51915256521  1.000000e+11
# 850      一般节点  51214123797  1.000000e+11
# 173      一般节点  49399787960  1.000000e+11
# 408      一般节点  51673456087  1.000000e+11
# 160      一般节点  50322958171  1.000000e+11
# 311      一般节点  51224734473  1.000000e+11
# 1057     一般节点  49117847542  1.000000e+11
# 445      一般节点  49484495071  1.000000e+11
# 392      一般节点  51278220999  1.000000e+11
# 13       一般节点  50161220081  1.000000e+11
# 793      一般节点  50601340670  1.000000e+11
# 644      一般节点  51384841448  1.000000e+11
# 148      一般节点  49953028308  1.000000e+11
# 45       一般节点  49416652053  1.000000e+11
# 122      一般节点  49735704801  1.000000e+11
# 757      一般节点  51467597716  1.000000e+11
# 35       网络核心  48368154112  1.000000e+11
# 142      网络核心  51256753219  1.000000e+11
# 566      网络核心  49995510331  1.000000e+11
# 66       网络核心  51023900961  1.000000e+11
# 63       网络核心  50401714739  1.000000e+11
# 324      网络核心  49665987866  1.000000e+11
# 533      网络核心  52135271000  1.000000e+11
# 554      网络核心  50311811210  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 485      网络核心  50529263033  1.000000e+11
# 152      网络核心  49178187887  1.000000e+11
# 18       网络核心  52195591947  1.000000e+11
# 331      网络核心  49834736741  1.000000e+11
# 489      网络核心  47826329156  1.000000e+11
# 349      网络核心  47569937466  1.000000e+11
# 373      网络核心  50339382092  1.000000e+11
# 58       网络核心  50609333179  1.000000e+11
# 442      网络核心  50594027588  1.000000e+11
# 415      网络核心  47741796615  1.000000e+11
# 428      网络核心  50678848280  1.000000e+11
# 881      网络核心  49268870810  1.000000e+11
# 600      网络核心  48884918110  1.000000e+11
# 925      网络核心  48414179107  1.000000e+11
# 424      网络核心  48754882922  1.000000e+11
# 363      网络核心  50252917820  1.000000e+11
# 330      网络核心  51277669375  1.000000e+11
# 11       网络核心  50703793815  1.000000e+11
# 125      网络核心  50242784823  1.000000e+11
# 738      网络核心  49820870504  1.000000e+11
# 488      网络核心  49653211362  1.000000e+11
# 53       网络核心  51342500152  1.000000e+11
# 620      网络核心  50207994896  1.000000e+11
# 134      网络核心  49228307349  1.000000e+11

# %%
def systematic_sampling(data, sample_size):
    N = len(data)  
    k = N // sample_size  
    start = np.random.randint(0, k)  
    indices = np.arange(start, N, k)[:sample_size] 
    sample = data.iloc[indices]  
    return sample

systematic_sample = systematic_sampling(primitive_data,50)
systematic_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 12          47        260        通辽       一般节点    2549      835      沈阳
# 34          96         99      呼和浩特       一般节点    1257      560      上海
# 56          96        346      呼和浩特       一般节点    1257      138      上海
# 78         180        188      呼和浩特       一般节点   36422      350      天津
# 100        474        422       哈尔滨       一般节点      96      141    呼和浩特
# 122        474       1272       哈尔滨       一般节点    2473     1043      吉林
# 144        591         98        绥化       一般节点    2701      195      大连
# 166        591       1300        绥化       一般节点    3443     1022      青岛
# 188       1997         44        天津       网络核心    2473     1053      吉林
# 210       1997        193        天津       网络核心    3213      606      重庆
# 232       1997        466        天津       网络核心    1756      796      北京
# 254       2050        296       石家庄       网络核心    2360       62      太原
# 276         47         74        通辽       一般节点    4561     1033      成都
# 298         63         62        通辽       一般节点     474      683     哈尔滨
# 320         96        134      呼和浩特       一般节点    3643      893      武汉
# 342        180         28      呼和浩特       一般节点    1536     1901      广州
# 364        180        256      呼和浩特       一般节点    4561      623      成都
# 386        474        673       哈尔滨       一般节点    1997      464      天津
# 408        591         13        绥化       一般节点     180      264    呼和浩特
# 430        591       1082        绥化       一般节点    1257      560      上海
# 452        787        325        玉溪       一般节点    2701      181      大连
# 474       2050        330       石家庄       网络核心    1756     1029      北京
# 496         47        259        通辽       一般节点    1129      910      上海
# 518       2050        271       石家庄       网络核心    2549     1070      沈阳
# 540         47        427        通辽       一般节点    2549     1430      沈阳
# 562         96        111      呼和浩特       一般节点    3443      101      青岛
# 584       1257        178        上海       网络核心    2194      180      唐山
# 606       1756        245        北京       网络核心    2994      488      洛阳
# 628        180         52      呼和浩特       一般节点     235     1621      北京
# 650       1756       1029        北京       网络核心     180      252    呼和浩特
# 672       1129        910        上海       网络核心    1997      250      天津
# 694       2549       1070        沈阳       网络核心    2994      270      洛阳
# 716       2549       1430        沈阳       网络核心    2994      488      洛阳
# 738       2473        803        吉林       一般节点     235     1621      北京
# 760       5058         70        南宁       一般节点      96      460    呼和浩特
# 782       1997        213        天津       网络核心     180      214    呼和浩特
# 804        180        264      呼和浩特       一般节点     474      475     哈尔滨
# 826       2360        215        太原       网络核心     474     1409     哈尔滨
# 848       2549        836        沈阳       网络核心     591      582      绥化
# 870        235       1661        北京       网络核心     787       63      玉溪
# 892       2994        486        洛阳       网络核心    1997       89      天津
# 914       3227        195        济南       网络核心      47      249      通辽
# 936       1385       1490        广州       网络核心    1997      727      天津
# 958       2701         47        大连       网络核心      47      259      通辽
# 980       4360        472        南京       一般节点      63      286      通辽
# 1002      2194        506        唐山       网络核心    3443      316      青岛
# 1024      1997        122        天津       网络核心    1997       85      天津
# 1046     36422        230        天津       网络核心     235     1506      北京
# 1068      2360        266        太原       网络核心    1536      681      广州
# 1090       235       1958        北京       网络核心   36539     1140      杭州
#
#      to_level      traffic     bandwidth
# 12       网络核心  50220958279  1.000000e+11
# 34       网络核心  49753614568  1.000000e+11
# 56       网络核心  47759033178  1.000000e+11
# 78       网络核心  49047066099  1.000000e+11
# 100      一般节点  48084671443  1.000000e+11
# 122      一般节点  49735704801  1.000000e+11
# 144      网络核心  50256295026  1.000000e+11
# 166      网络核心  49657631257  1.000000e+11
# 188      一般节点  49664584385  1.000000e+11
# 210      网络核心            0  1.000000e+11
# 232      网络核心  49492964585  1.000000e+11
# 254      网络核心  50417234362  1.000000e+11
# 276      网络核心  50819524115  1.000000e+11
# 298      一般节点  50533229665  1.000000e+11
# 320      网络核心  48498103572  1.000000e+11
# 342      网络核心  50028471161  1.000000e+11
# 364      网络核心  49917991196  1.000000e+11
# 386      网络核心  49632718644  1.000000e+11
# 408      一般节点  51673456087  1.000000e+11
# 430      网络核心  49355162407  1.000000e+11
# 452      网络核心  49891276242  1.000000e+11
# 474      网络核心  50441063718  1.000000e+11
# 496      网络核心  49611318298  1.000000e+11
# 518      网络核心            0  1.000000e+11
# 540      网络核心  50264080533  1.000000e+11
# 562      网络核心  51065224623  1.000000e+11
# 584      网络核心  49865079269  1.000000e+11
# 606      网络核心  50430382603  1.000000e+11
# 628      网络核心  49227038603  1.000000e+11
# 650      一般节点  49962829154  1.000000e+11
# 672      网络核心  49497929566  1.000000e+11
# 694      网络核心  50339700274  1.000000e+11
# 716      网络核心  48630063258  1.000000e+11
# 738      网络核心  49820870504  1.000000e+11
# 760      一般节点  49703011825  1.000000e+11
# 782      一般节点  52078865540  1.000000e+11
# 804      一般节点  49012460413  1.000000e+11
# 826      一般节点  49759684322  1.000000e+11
# 848      一般节点  51807875798  1.000000e+11
# 870      一般节点  50339834207  1.000000e+11
# 892      网络核心  49567784427  1.000000e+11
# 914      一般节点            0  1.000000e+11
# 936      网络核心  50200042873  1.000000e+11
# 958      一般节点  51351550689  1.000000e+11
# 980      一般节点  49837582425  1.000000e+11
# 1002     网络核心  50732764201  1.000000e+11
# 1024     网络核心  48608837194  1.000000e+11
# 1046     网络核心  51759720190  1.000000e+11
# 1068     网络核心  51667076933  1.000000e+11
# 1090     一般节点  48668702701  1.000000e+11

# %%
def cluster_sampling(data, num_clusters, cluster_column):
    unique_clusters = data[cluster_column].unique()
    selected_clusters = np.random.choice(unique_clusters, num_clusters, replace=False)
    sample = data[data[cluster_column].isin(selected_clusters)]
    return sample

cluster_sample = cluster_sampling(primitive_data, 3, 'from_city')
cluster_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 34          96         99      呼和浩特       一般节点    1257      560      上海
# 35          96        102      呼和浩特       一般节点    2549      852      沈阳
# 36          96        105      呼和浩特       一般节点    3227      781      济南
# 37          96        108      呼和浩特       一般节点    2360      236      太原
# 38          96        111      呼和浩特       一般节点    3227      468      济南
# ...        ...        ...       ...        ...     ...      ...     ...
# 1065      3227        103        济南       网络核心    2360      215      太原
# 1070      1257        138        上海       网络核心    2050      443     石家庄
# 1091      1129        910        上海       网络核心    4515      652      西安
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
#
#      to_level      traffic     bandwidth
# 34       网络核心  49753614568  1.000000e+11
# 35       网络核心  48368154112  1.000000e+11
# 36       网络核心  50585574378  1.000000e+11
# 37       网络核心  48210462086  1.000000e+11
# 38       网络核心  48575689938  1.000000e+11
# ...       ...          ...           ...
# 1065     网络核心  51248496177  1.000000e+11
# 1070     网络核心  48498470042  1.000000e+11
# 1091     网络核心  48912516167  1.000000e+11
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
#
# [222 rows x 10 columns]
